# %%
# !pip install streamlit
# !pip install streamlit_option_menu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.4/823.4 kB 15.9 MB/s eta 0:00:00
# ...

# %%
import os
import pickle
import streamlit as st
from streamlit_option_menu import option_menu

st.set_page_config(page_title="Car Insurance Chatbot",
                   layout="wide")
